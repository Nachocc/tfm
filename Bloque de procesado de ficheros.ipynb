# %%
#Imports
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
import glob
import datetime
import os
from pathlib import Path

# %%
#Path to file
path = '/home/nacho/TFM/ficheros/'


#Column names to process the files
col_names = ["date", "Type", "Type2", "Traffic", "Number_B", "Number", "Duration", "Duration2", 
             "A", "VAT", "VAT Amount", "Total Prize", "B", "Product"]
cols = ["date", "Type", "Type2", "Traffic", "Number_B", "Duration" ]
#chunksize = 10000
traffic_list = ['Llamada internacional zona 1', 'Llamada internacional zona 2', 
                'Llamada internacional zona 3', 'Llamada internacional zona 4','Llamada internacional zona 5']

#Call mapping to convert callids into something readable
call_mapping = {'Call_Mo_HomeNetwork_NA_CheckBalance_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_CustomerService_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_IntZone1_NA_AllDays' : 'Llamada internacional zona 1',
 'Call_Mo_HomeNetwork_NA_IntZone2_NA_AllDays' : 'Llamada internacional zona 2',
 'Call_Mo_HomeNetwork_NA_IntZone3_NA_AllDays' : 'Llamada internacional zona 3',
 'Call_Mo_HomeNetwork_NA_IntZone4_NA_AllDays' : 'Llamada internacional zona 4',
 'Call_Mo_HomeNetwork_NA_IntZone5_NA_AllDays' : 'Llamada internacional zona 5',
 'Call_Mo_HomeNetwork_NA_NatFixed_NA_AllDays' : 'Llamada nacional',
 'Call_Mo_HomeNetwork_NA_NatFixed_NA_AllDays_Lepanto': 'Llamada nacional',
 'Call_Mo_HomeNetwork_NA_NatMobile_NA_AllDays': 'Llamada nacional',
 'Call_Mo_HomeNetwork_NA_NatMobile_NA_AllDays_Lepanto': 'Llamada nacional',
 'Call_Mo_HomeNetwork_NA_Nomadic_NA_AllDays': 'Llamada nacional',
 'Call_Mo_HomeNetwork_NA_Special010_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special012_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special060_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special061_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special092_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special1002_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special1004_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special11811_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special11822_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special11843_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special11850_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special1____NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special800_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special80XN3_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special900_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special901_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special902N1_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special902_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Superonnet_NA_AllDays': 'Llamada nacional',
 'Call_Mo_HomeNetwork_NA_Superonnet_NA_AllDays_Lepanto': 'Llamada nacional',
 'Call_Mo_HomeNetwork_NA_VoiceMail_NA_AllDays':'Llamada de servicio',
 'Call_Mo_RoamingZone1_NA_National_NA_AllDays':'Llamada roaming Zona 1',
 'Call_Mo_RoamingZone1_NA_National_NA_AllDays_Lepanto':'Llamada roaming Zona 1',
 'Call_Mo_RoamingZone1_NA_RoaZone1_NA_AllDays':'Llamada roaming Zona 1',
 'Call_Mo_RoamingZone1_NA_VoiceMail_CFB_AllDays':'Llamada roaming Zona 1',
 'Call_Mo_RoamingZone2_NA_VoiceMail_CFB_AllDays':'Llamada roaming Zona 2',
 'Call_Mo_RoamingZone3_NA_National_NA_AllDays':'Llamada roaming Zona 3',
 'Call_Mo_RoamingZone3_NA_RoaZone3_NA_AllDays':'Llamada roaming Zona 3',
 'IPCall_Mo_HomeNetwork_NA_IntZone1_NA_AllDays':'Llamada internacional Voz IP',
 'IPCall_Mo_HomeNetwork_NA_IntZone2_NA_AllDays':'Llamada internacional Voz IP',
 'IPCall_Mo_HomeNetwork_NA_IntZone3_NA_AllDays':'Llamada internacional Voz IP',
 'IPCall_Mo_HomeNetwork_NA_IntZone5_NA_AllDays':'Llamada internacional Voz IP',
 'IPCall_Mo_HomeNetwork_NA_NatFixed_NA_AllDays':'Llamada nacional Voz IP',
 'IPCall_Mo_HomeNetwork_NA_NatMobile_NA_AllDays':'Llamada nacional Voz IP',
 'IPCall_Mo_HomeNetwork_NA_Special800_NA_AllDays':'Llamada nacional Voz IP',
 'IPCall_Mo_HomeNetwork_NA_Special900_NA_AllDays':'Llamada nacional Voz IP',
 'IPCall_Mo_HomeNetwork_NA_Superonnet_NA_AllDays':'Llamada nacional Voz IP',
 'Call_Mo_HomeNetwork_NA_Special905N3E_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_RoamingZone1_NA_RoaZone3_NA_AllDays':'Llamada roaming Zona 1',
 'Call_Mo_HomeNetwork_NA_Special062_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special088_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special080_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special11888_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special11880_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special091_NA_AllDays':'Llamada de servicio',
 'Call_Mo_RoamingZone2_NA_National_NA_AllDays':'Llamada roaming Zona 2',
 'Call_Mo_HomeNetwork_NA_Special011_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special1006_NA_AllDays':'Llamada de servicio',
 'Call_Mo_RoamingZone2_NA_RoaZone3_NA_AllDays':'Llamada roaming Zona 2',
 'Call_Mo_HomeNetwork_NA_Special80XN1_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special085_NA_AllDays':'Llamada de servicio',
 'Call_Mo_HomeNetwork_NA_Special905N3T_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_RoamingZone1_NA_Superonnet_NA_AllDays':'Llamada roaming Zona 1',
 'Call_Mo_RoamingZone1_NA_RoaZone1_NA_AllDays_Lepanto':'Llamada roaming Zona 1',
 'IPCall_Mo_HomeNetwork_NA_Nomadic_NA_AllDays':'Llamada nacional Voz IP',
 'Call_Mo_HomeNetwork_NA_VocalNomadic_NA_AllDays': 'Llamada nacional',
 'Call_Mo_RoamingZone3_NA_VoiceMail_CFB_AllDays':'Llamada roaming Zona 3',
 'Call_Mo_HomeNetwork_NA_Special065_NA_AllDays':'Llamada de servicio',
 'Call_Mo_RoamingZone2_NA_RoaZone2_NA_AllDays':'Llamada roaming Zona 2',
 'Call_Mo_HomeNetwork_NA_UIFN_NA_AllDays':'Llamada de servicio',
 'Call_Mo_RoamingZone2_NA_RoaZone1_NA_AllDays':'Llamada roaming Zona 2',
 'Call_Mo_HomeNetwork_NA_Special80XN2_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special902N2_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Special11818_NA_AllDays':'Llamada numeros especiales',
 'IPCall_Mo_HomeNetwork_NA_NatTuenti_NA_AllDays':'Llamada nacional Voz IP',
 'Call_Mo_RoamingZone1_NA_RoaZone2_NA_AllDays':'Llamada roaming Zona 1',
 'IPCall_Mo_HomeNetwork_NA_IntZone4_NA_AllDays':'Llamada internacional Voz IP',
 'Call_Mo_HomeNetwork_NA_Special11825_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_RoamingZone3_NA_RoaZone2_NA_AllDays':'Llamada roaming Zona 3',
 'Call_Mo_HomeNetwork_NA_Special11860_NA_AllDays':'Llamada numeros especiales',
 'Call_Mo_HomeNetwork_NA_Nomadic_NA_AllDays_Lepanto': 'Llamada nacional'}

#Prefixes of the call records
list_int_prefix = pd.read_table('/home/nacho/TFM/Int_prefix', header=None, names=['Country', 'Prefix', 'TimeZone', 'UTC'])
list_int_prefix.drop(labels=['TimeZone', 'UTC'], axis=1, inplace=True)
list_int_prefix['Prefix'] = list_int_prefix['Prefix'].apply(lambda x: str(x)[1:])
list_int_prefix['Prefix'] = list_int_prefix['Prefix'].str.split(' ').str[0]
list_int_prefix['Prefix'] = list_int_prefix['Prefix'].str.split('[').str[0]
prefixes = set(list_int_prefix['Prefix'])

# %%
#Read CSV block
dirs = os.listdir(path)
all_files = glob.glob(path + "/*.csv")
data_frame = pd.DataFrame()
list2 = []

for file in all_files:
    print(file)
    df = pd.read_csv(file, error_bad_lines=False, skiprows=10, sep=";", names=col_names, usecols=cols, low_memory=True)
    #Get client ids and client type and add it as a column
    ids = df["Type"]
    ids2 = df["Type2"]
    mask_ids = ids.str.isnumeric()
    df_index = ids.where(mask_ids).fillna(method='ffill').fillna(method='bfill').tolist()
    mask_ids2 = ids2.str.isnumeric()
    df_index2 = ids2.where(mask_ids).fillna(method='ffill').fillna(method='bfill').tolist()
    df['ids'] = df_index 
    df['type_cust'] = df_index2
       
    #
    df['Type2'].replace(call_mapping, inplace=True) #Call mapping of the different call destinations
    df2 = pd.DataFrame(df, columns=['ids', 'date', 'Type2', 'Traffic', 'Number_B', 'Duration', 'type_cust'])
    df2 = df2[df2['Traffic'] == 'VOICE_MO'] #Get only the call records
    df2 = df2[df2['type_cust'] != '1'] #Taking out employees from the list
    df2 = df2[df2['Type2'].isin(traffic_list)] #taking only the 
    df_final = df2
    df_final['Duration'] = pd.to_numeric(df_final['Duration'])
    df_final['date'] = pd.to_datetime(df_final['date'])
    #Formating the call time and date
    df_final['Date'] = df_final['date'].apply(lambda x: x.strftime('%Y%m%d'))
    df_final['Time'] = df_final['date'].apply(lambda x: x.strftime('%H%M'))
    df_final['Prefix'] = df_final['Number_B'].apply(lambda x: x[1:1] if x[1:1] in prefixes else (x[1:2] if x[1:2] in prefixes
                                                    else(x[1:3] if x[1:3] in prefixes else x[1:4])))
    df_final = df_final[['Date', 'Time', 'Type2', 'Traffic', 'Prefix', 'Duration', 'type_cust']]
    df_final

    list2.append(df_final)
data_frame = pd.concat(list2) #Joining all the files into a final dataser

data_frame.to_csv(path + 'dataset') #Export it as a csv
# Out:
# /home/nacho/TFM/ficheros/Run_Tuenti_InvoicesData_iteration35of39_part1of1_2017-12-18_to_2018-01-17_20180118231147.csv
# /home/nacho/TFM/ficheros/Run_Tuenti_InvoicesData_iteration22of42_part1of1_2018-02-18_to_2018-03-17_20180320193736.csv
# /home/nacho/TFM/ficheros/Run_Tuenti_InvoicesData_iteration34of37_part1of1_2017-09-18_to_2017-10-17_20171027144647.csv
# /home/nacho/TFM/ficheros/Run_Tuenti_InvoicesData_iteration30of37_part1of1_2017-09-18_to_2017-10-17_20171027144647.csv
# /home/nacho/TFM/ficheros/Run_Tuenti_InvoicesData_iteration17of46_part1of1_2018-05-18_to_2018-06-17_20180619184322.csv
# /home/nacho/TFM/ficheros/Run_Tuenti_InvoicesData_iteration04of41_part1of1_2018-01-18_to_2018-02-17_20180220192044.csv
# /home/nacho/TFM/ficheros/Run_Tuenti_InvoicesData_iteration02of42_part1of1_2018-02-18_to_2018-03-17_20180320193736.csv
# /home/nacho/TFM/ficheros/Run_Tuenti_InvoicesData_iteration22of43_part1of1_2018-03-18_to_2018-04-17_20180424173603.csv
# ...
